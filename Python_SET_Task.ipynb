# %% [markdown]
# # SET
#  - Multiple value of Different/Same Data type
#  - denote with {}
#  - Duplicate values not allowed
#  - Insertion order not maintain
#  - Indexing and Scilicing not allowed
#  - Set Object are mutable (add,remove.update)

# %% [markdown]
# ## Creation of set
#  - Note While creating and empty set we should use set()
#  - {} empty reprent dict type

# %%
s= {}
print(s)
print(type(s))
# Out:
# {}
# <class 'dict'>

# %%
s= set()
print(s)
print(type(s))
# Out:
# set()
# <class 'set'>

# %%
s = {10,20,30}
print(s)
print(type(s))
# Out:
# {10, 20, 30}
# <class 'set'>

# %%
s =set(range(0,9))
print(s)
print(type(s))
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 8}
# <class 'set'>

# %% [markdown]
# ## Function of set

# %% [markdown]
# ### add() :- Add an element to a set.
#   - It cannot add list/dict. Accept only immutable item

# %%
s ={10,20,30,40,50}
s
# Out:
# {10, 20, 30, 40, 50}

# %%
s.add(78)
s
# Out:
# {10, 20, 30, 40, 50, 78}

# %%
s.add("viraj")

# %%
s
# Out:
# {10, 20, 30, 40, 50, 78, 'viraj'}

# %%
s.add("FSDS")
s
# Out:
# {10, 20, 30, 40, 50, 78, 'FSDS', 'viraj'}

# %% [markdown]
# ### clear() : - clear element in set

# %%
s1 = {"viraj","fads","AI","ML"}
s1
# Out:
# {'AI', 'ML', 'fads', 'viraj'}

# %%
s1.clear()
s1
# Out:
# set()

# %% [markdown]
# ### copy : - copy one set to another set

# %%
s
# Out:
# {10, 20, 30, 40, 50, 78, 'FSDS', 'viraj'}

# %%
s1 = s.copy()
s1
# Out:
# {10, 20, 30, 40, 50, 78, 'FSDS', 'viraj'}

# %% [markdown]
# ### pop() : -Remove and return an arbitrary set element

# %%
s1
# Out:
# {10, 20, 30, 40, 50, 78, 'FSDS', 'viraj'}

# %%
s1.pop()
# Out:
# 40

# %%
s1.pop(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 s1.pop(1)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
s1.pop()
# Out:
# 10

# %% [markdown]
# ### remove() :- Remove an element from a set; it must be a member.

# %%
s
# Out:
# {10, 20, 30, 40, 50, 78, 'FSDS', 'viraj'}

# %%
s.remove(78)

# %%
s
# Out:
# {10, 20, 30, 40, 50, 'FSDS', 'viraj'}

# %%
s.remove(67)
s
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 s.remove(67)
#       2 s
#
# KeyError: 67

# %%
s.remove(50)
s
# Out:
# {10, 20, 30, 40, 'FSDS', 'viraj'}

# %% [markdown]
# ### discard() :- This function is used for removing an specified element from set object.
#  - if the specified element does not exist in set object,we never get KeyError.
#  - Syntax:- setobj.discard(Value)

# %%
s
# Out:
# {10, 20, 30, 40, 'FSDS', 'viraj'}

# %%
s.discard(10)

# %%
s
# Out:
# {20, 30, 40, 'FSDS', 'viraj'}

# %%
s.discard(88)

# %% [markdown]
# ### Union() :- we can use this fucntion to return all the elemnt form present from both set
#    - union or | used

# %%
s1= {10,20,30,40}
s2={40,50,60,70}
print(s1)
print(s2)
# Out:
# {40, 10, 20, 30}
# {40, 50, 60, 70}

# %%
s1.union(s2)
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
s1 | s2
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %% [markdown]
# ### intersection() :- retrun common element present in both
#  - intersection() or &

# %%
s1= {10,20,30,40,50}
s2={40,50,60,70}
print(s1)
print(s2)
# Out:
# {50, 20, 40, 10, 30}
# {40, 50, 60, 70}

# %%
s1.intersection(s2)
# Out:
# {40, 50}

# %%
s2.intersection(s1)
# Out:
# {40, 50}

# %%
s3= {10,20,30}
s4={40,50,60,70}
print(s3)
print(s4)
# Out:
# {50, 20, 40, 10, 30}
# {40, 50, 60, 70}

# %%
s3.intersection(s4)
# Out:
# set()

# %%
s1 & s2
# Out:
# {40, 50}

# %% [markdown]
# ### diffrence() :- return the element which are present in x but not in y
#    - diffrence() or - used

# %%
s1= {10,20,30,40,50}
s2={40,50,60,70}
print(s1)
print(s2)
# Out:
# {50, 20, 40, 10, 30}
# {40, 50, 60, 70}

# %%
s1.difference(s2)
# Out:
# {10, 20, 30}

# %%
s2.difference(s1)
# Out:
# {60, 70}

# %%
print(s1-s2)
# Out:
# {10, 20, 30}

# %%
print(s2-s1)
# Out:
# {60, 70}

# %% [markdown]
# ### symmetric_diffrence() :- return elemnts present in either xor y but not in both
#   - symmetric_diffrence or ^ used

# %%
s1= {10,20,30,40,50}
s2={40,50,60,70}
print(s1)
print(s2)
print(s3)
print(s4)
# Out:
# {50, 20, 40, 10, 30}
# {40, 50, 60, 70}
# {10, 20, 30}
# {40, 50, 60, 70}

# %%
s1.symmetric_difference(s2)
# Out:
# {10, 20, 30, 60, 70}

# %%
s2.symmetric_difference(s1)
# Out:
# {10, 20, 30, 60, 70}

# %%
 print(s1^s3)
# Out:
# {40, 50}

# %%
s2.symmetric_difference(s4)
# Out:
# set()

# %% [markdown]
# ## symmetric_difference_update(): update the set
#  - Keeps only the elements that are NOT common between sets A and B.

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5}

A.symmetric_difference_update(B)
print(A)
# Out:
# {1, 2, 5}

# %% [markdown]
# ### difference_update() :- Removes the elements from set A that are present in set B.

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5}

A.difference_update(B)
print(A.isdisjoint)
# Out:
# {1, 2}

# %% [markdown]
# ## isdisjoint() :- Two sets are said to be disjoint sets if they have no common element

# %%
A = {1,2,3,4,5,6,7,8,9} 
B = {3,4,5,6,7,8} 
C = {10,20,30,40}

# %%
A.isdisjoint(B)
# Out:
# False

# %%
C.isdisjoint(B)
# Out:
# True

# %%
A.isdisjoint(C)
# Out:
# True

# %% [markdown]
# ## issubset() :- Set B is said to be the subset of set A if all elements of B are peresent inside A

# %%
A.issubset(B)
# Out:
# False

# %%
B.issubset(A)
# Out:
# True

# %%
C.issubset(A)
# Out:
# False

# %% [markdown]
# ## issuperset() :-  # Set A is said to be the superset of set B if all elements of B are present inside A

# %%
A.issuperset(B)
# Out:
# True

# %%
B.issuperset(A)
# Out:
# False

# %%
C.issuperset(B)
# Out:
# False

# %% [markdown]
# ## update() :- The update() method updates the current set, by adding items from another set (or any other iterable).
#  - As a shortcut, you can use the |= operator instead, see example below.

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}
z = {"cherry", "micra", "bluebird"}

x.update(y, z)

print(x)
# Out:
# {'apple', 'banana', 'microsoft', 'google', 'micra', 'bluebird', 'cherry'}
