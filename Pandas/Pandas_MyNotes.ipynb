# %% [markdown]
# # Intro to Dataframe

# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=["A","B","C"])   # we can al;so giv indx attrubite to index name like  index=["x","y","z"]

# %%
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.index.tolist()
# Out:
# [0, 1, 2]

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0 bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.shape
# Out:
# (3, 3)

# %%
df['A'].unique()   # give unique value in row
# Out:
# array([1, 4, 7])

# %%
df.size
# Out:
# 9

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# A    int64
# B    int64
# C    int64
# dtype: object

# %%
coffee = pd.read_csv(r"C:\Users\ladvi\Downloads\coffee.csv")

# %%
coffee_new = coffee   # refer to the same object  any chnages made reflect oin both 


coffee_new = coffee.copy()    # create a shallow copy   noi changes reflect

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.tail()
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes

# %%
coffee.describe()
# Out:
#        Units Sold
# count   14.000000
# mean    32.857143
# std      9.346798
# min     15.000000
# 25%     26.250000
# 50%     35.000000
# 75%     38.750000
# max     45.000000

# %%
results = pd.read_parquet(r"C:\Users\ladvi\Downloads\results.parquet")
bios = pd.read_csv(r"C:\Users\ladvi\Downloads\bios.csv")

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %% [markdown]
# ## Accesing Data with Pandas

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.sample(10)  # Return a random sample of items from an axis of object.
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 9      Friday       Latte          35
# 4   Wednesday    Espresso          35
# 13     Sunday       Latte          35
# 3     Tuesday       Latte          20
# 2     Tuesday    Espresso          30
# 5   Wednesday       Latte          25
# 1      Monday       Latte          15
# 11   Saturday       Latte          35
# 6    Thursday    Espresso          40

# %%
coffee.sample(10,random_state=1)   # ranom_state for non changable  the data ]
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte          20
# 7    Thursday       Latte          30
# 6    Thursday    Espresso          40
# 2     Tuesday    Espresso          30
# 10   Saturday    Espresso          45
# 4   Wednesday    Espresso          35
# 1      Monday       Latte          15
# 12     Sunday    Espresso          45
# 0      Monday    Espresso          25
# 13     Sunday       Latte          35

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# loc allow us to filter throe column and roiw of our datfareme 
# coffee.loc[rows,column]
# loc

# Label-based

# Uses row/column names

# End index IS included

coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[[0,1,5]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 5  Wednesday       Latte          25

# %%
coffee.loc[0:9]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35

# %%
coffee.loc[5:]
# Out:
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[3:10,"Day"]
# Out:
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# Name: Day, dtype: object

# %%
coffee.loc[3:10,["Day","Units Sold"]]
# Out:
#           Day  Units Sold
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45

# %%
# loc

# Label-based

# Uses row/column names

# End index IS included


coffee.iloc[:,[0,2]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee.iloc[2:,::-1]
# Out:
#     Units Sold Coffee Type        Day
# 2           30    Espresso    Tuesday
# 3           20       Latte    Tuesday
# 4           35    Espresso  Wednesday
# 5           25       Latte  Wednesday
# 6           40    Espresso   Thursday
# 7           30       Latte   Thursday
# 8           45    Espresso     Friday
# 9           35       Latte     Friday
# 10          45    Espresso   Saturday
# 11          35       Latte   Saturday
# 12          45    Espresso     Sunday
# 13          35       Latte     Sunday

# %%
coffee['Day']
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.Units Sold
# Out:
#   Cell In[79], line 1
#     coffee.Units Sold
#                  ^
# SyntaxError: invalid syntax

# %%
coffee['Units Sold']
# Out:
# 0     25
# 1     15
# 2     30
# 3     20
# 4     35
# 5     25
# 6     40
# 7     30
# 8     45
# 9     35
# 10    45
# 11    35
# 12    45
# 13    35
# Name: Units Sold, dtype: int64

# %%
coffee.sort_values('Units Sold',ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 8      Friday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 9      Friday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
coffee.sort_values(["Units Sold","Coffee Type"],ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          30
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
coffee.sort_values(["Units Sold","Coffee Type"],ascending=[1,0])
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %% [markdown]
# ## Filtering Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.loc[bios["height_cm"]>215.0]  # filter + update use loc
# Out:
#         athlete_id                   name   born_date               born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19         Moskva (Moscow)
# 5583          5606   Paulinho Villas Boas  1963-01-26               São Paulo
# 5673          5696         Gunther Behnke  1963-01-19              Leverkusen
# 5716          5739               Uwe Blab  1962-03-26        München (Munich)
# 5781          5804         Tommy Burleson  1952-02-24               Crossnore
# 5796          5819          Andy Campbell  1956-07-21               Melbourne
# 6223          6250            Lars Hansen  1954-09-27  København (Copenhagen)
# 6270          6298            Hu Zhangbao  1963-04-05                     NaN
# 6409          6440       Sergey Kovalenko  1947-08-11                     NaN
# 6420          6451          Jānis Krūmiņš  1930-01-30                   Cēsis
# 6504          6537            Luc Longley  1969-01-19               Melbourne
# ...

# %%
bios.loc[bios["height_cm"]>215.0,["name","height_cm"]]  # filter + update use loc
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
bios[bios['height_cm']>220]
# Out:
#         athlete_id             name   born_date       born_city  \
# 5673          5696   Gunther Behnke  1963-01-19      Leverkusen
# 5781          5804   Tommy Burleson  1952-02-24       Crossnore
# 6978          7013  Arvydas Sabonis  1964-12-19          Kaunas
# 89070        89782         Yao Ming  1980-09-12  Xuhui District
# 89075        89787   Roberto Dueñas  1975-11-01          Madrid
# 120266      122147     Zhang Zhaoxu  1987-11-18         Binzhou
#
#                 born_region born_country                         NOC  \
# 5673    Nordrhein-Westfalen          GER                     Germany
# 5781         North Carolina          USA               United States
# 6978                 Kaunas          LTU      Lithuania Soviet Union
# 89070              Shanghai          CHN  People's Republic of China
# 89075                Madrid          ESP                       Spain
# 120266             Shandong          CHN  People's Republic of China
#
# ...

# %%
bios[bios["height_cm"]>215][["name","height_cm"]]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
bios[(bios["height_cm"]>215) & (bios["born_country"]=="USA")]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios.loc[(bios["height_cm"]>215) & (bios["born_country"]=="USA")]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios[bios["name"].str.contains("Keith")]
# Out:
#         athlete_id                  name   born_date         born_city  \
# 1897          1907          Keith Hanlon  1966-09-01               NaN
# 3505          3517         Keith Wallace  1961-03-29           Preston
# 6228          6255         Keith Hartley  1940-10-15         Vancouver
# 8898          8946           Keith Mwila  1966-01-01               NaN
# 12053        12118          Keith Hervey  1898-11-03            Fulham
# ...            ...                   ...         ...               ...
# 109900      111105     Keith Cumberpatch  1927-08-25      Christchurch
# 115973      117348       Keith Sanderson  1975-02-02          Plymouth
# 117676      119195          Duncan Keith  1983-07-16          Winnipeg
# 122121      124176        Keith Ferguson  1979-09-07              Sale
# 127310      129749  Tracy Keith-Matchitt  1990-03-30  Palmerston North
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios["name"].str.contains("keith",case=False)]
# Out:
#         athlete_id                  name   born_date         born_city  \
# 1897          1907          Keith Hanlon  1966-09-01               NaN
# 3505          3517         Keith Wallace  1961-03-29           Preston
# 6228          6255         Keith Hartley  1940-10-15         Vancouver
# 8898          8946           Keith Mwila  1966-01-01               NaN
# 12053        12118          Keith Hervey  1898-11-03            Fulham
# ...            ...                   ...         ...               ...
# 109900      111105     Keith Cumberpatch  1927-08-25      Christchurch
# 115973      117348       Keith Sanderson  1975-02-02          Plymouth
# 117676      119195          Duncan Keith  1983-07-16          Winnipeg
# 122121      124176        Keith Ferguson  1979-09-07              Sale
# 127310      129749  Tracy Keith-Matchitt  1990-03-30  Palmerston North
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios["name"].str.contains("keith|patrick",case=False)]
# Out:
#         athlete_id               name   born_date              born_city  \
# 6                7      Patrick Chila  1969-11-27            Ris-Orangis
# 119            120   Patrick Wheatley  1899-01-20                Vryheid
# 319            320  Patrick De Koning  1961-04-23            Dendermonde
# 1897          1907       Keith Hanlon  1966-09-01                    NaN
# 2115          2125       Patrick Jopp  1962-01-08                    NaN
# ...            ...                ...         ...                    ...
# 143975      147633  Patrick Chinyemba  2001-01-03                    NaN
# 144172      147850      Patrick Jakob  1996-10-17  Sankt Johann in Tirol
# 144547      148239  Patrick Galbraith  1986-03-11              Haderslev
# 144565      148257    Patrick Russell  1993-01-04               Gentofte
# 145435      149158  Patrick Gasienica  1998-11-28                McHenry
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios["born_country"].isin(["USA","FRA","IND"]) & bios["name"].str.startswith("Keith")]
# Out:
#         athlete_id                name   born_date             born_city  \
# 50929        51288        Keith Carter  1924-08-30                 Akron
# 51185        51544       Keith Russell  1948-01-15                  Mesa
# 52913        53288      Keith Erickson  1944-04-19         San Francisco
# 62678        63144        Keith Notary  1960-01-22        Merritt Island
# 77550        78141       Keith Brantly  1962-05-23  Scott Air Force Base
# 84097        84766  Keith Christiansen  1944-07-14   International Falls
# 94646        95413         Keith Meyer  1938-06-20                Geneva
# 97499        98286       Keith Tkachuk  1972-03-28               Melrose
# 98068        98860       Keith Wegeman  1929-08-28                Denver
# 99921       100722        Keith Carney  1970-02-03            Providence
# 115973      117348     Keith Sanderson  1975-02-02              Plymouth
#
#           born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios.query('born_country =="USA" and born_city == "Seattle"')
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
# ...

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee['price'] = 4.99

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new_price
# 0     Monday    Espresso          25       3.99
# 1     Monday       Latte          15       5.99
# 2    Tuesday    Espresso          30       3.99
# 3    Tuesday       Latte          20       5.99
# 4  Wednesday    Espresso          35       3.99

# %%
import numpy as np
coffee['new_price'] = np.where(coffee['Coffee Type']== "Espresso",3.99,5.99)

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new_price
# 0     Monday    Espresso          25       3.99
# 1     Monday       Latte          15       5.99
# 2    Tuesday    Espresso          30       3.99
# 3    Tuesday       Latte          20       5.99
# 4  Wednesday    Espresso          35       3.99

# %%
coffee['Coffee Type'].unique()
# Out:
# array(['Espresso', 'Latte'], dtype=object)

# %%
coffee['Day'].unique()
# Out:
# array(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday',
#        'Sunday'], dtype=object)

# %%
coffee.drop(0)
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 1      Monday       Latte          15   4.99       5.99
# 2     Tuesday    Espresso          30   4.99       3.99
# 3     Tuesday       Latte          20   4.99       5.99
# 4   Wednesday    Espresso          35   4.99       3.99
# 5   Wednesday       Latte          25   4.99       5.99
# 6    Thursday    Espresso          40   4.99       3.99
# 7    Thursday       Latte          30   4.99       5.99
# 8      Friday    Espresso          45   4.99       3.99
# 9      Friday       Latte          35   4.99       5.99
# 10   Saturday    Espresso          45   4.99       3.99
# 11   Saturday       Latte          35   4.99       5.99
# 12     Sunday    Espresso          45   4.99       3.99
# 13     Sunday       Latte          35   4.99       5.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  price
# 0      Monday    Espresso          25       3.99   4.99
# 1      Monday       Latte          15       5.99   4.99
# 2     Tuesday    Espresso          30       3.99   4.99
# 3     Tuesday       Latte          20       5.99   4.99
# 4   Wednesday    Espresso          35       3.99   4.99
# 5   Wednesday       Latte          25       5.99   4.99
# 6    Thursday    Espresso          40       3.99   4.99
# 7    Thursday       Latte          30       5.99   4.99
# 8      Friday    Espresso          45       3.99   4.99
# 9      Friday       Latte          35       5.99   4.99
# 10   Saturday    Espresso          45       3.99   4.99
# 11   Saturday       Latte          35       5.99   4.99
# 12     Sunday    Espresso          45       3.99   4.99
# 13     Sunday       Latte          35       5.99   4.99

# %%
coffee.drop(columns=['price'])
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  price
# 0      Monday    Espresso          25       3.99   4.99
# 1      Monday       Latte          15       5.99   4.99
# 2     Tuesday    Espresso          30       3.99   4.99
# 3     Tuesday       Latte          20       5.99   4.99
# 4   Wednesday    Espresso          35       3.99   4.99
# 5   Wednesday       Latte          25       5.99   4.99
# 6    Thursday    Espresso          40       3.99   4.99
# 7    Thursday       Latte          30       5.99   4.99
# 8      Friday    Espresso          45       3.99   4.99
# 9      Friday       Latte          35       5.99   4.99
# 10   Saturday    Espresso          45       3.99   4.99
# 11   Saturday       Latte          35       5.99   4.99
# 12     Sunday    Espresso          45       3.99   4.99
# 13     Sunday       Latte          35       5.99   4.99

# %%
coffee.drop(columns=["price"],inplace=True)

# %%
coffee['revenue'] = coffee['Units Sold'] * coffee['price']

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue
# 0      Monday    Espresso          25       3.99    99.75
# 1      Monday       Latte          15       5.99    89.85
# 2     Tuesday    Espresso          30       3.99   119.70
# 3     Tuesday       Latte          20       5.99   119.80
# 4   Wednesday    Espresso          35       3.99   139.65
# 5   Wednesday       Latte          25       5.99   149.75
# 6    Thursday    Espresso          40       3.99   159.60
# 7    Thursday       Latte          30       5.99   179.70
# 8      Friday    Espresso          45       3.99   179.55
# 9      Friday       Latte          35       5.99   209.65
# 10   Saturday    Espresso          45       3.99   179.55
# 11   Saturday       Latte          35       5.99   209.65
# 12     Sunday    Espresso          45       3.99   179.55
# 13     Sunday       Latte          35       5.99   209.65

# %%
coffee.rename(columns={'new_price':'price'},inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25   3.99
# 1      Monday       Latte          15   5.99
# 2     Tuesday    Espresso          30   3.99
# 3     Tuesday       Latte          20   5.99
# 4   Wednesday    Espresso          35   3.99
# 5   Wednesday       Latte          25   5.99
# 6    Thursday    Espresso          40   3.99
# 7    Thursday       Latte          30   5.99
# 8      Friday    Espresso          45   3.99
# 9      Friday       Latte          35   5.99
# 10   Saturday    Espresso          45   3.99
# 11   Saturday       Latte          35   5.99
# 12     Sunday    Espresso          45   3.99
# 13     Sunday       Latte          35   5.99

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios_new = bios.copy()

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new['first_name'] = bios_new['name'].str.split(" ").str[0]

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'],errors='coerce')

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   athlete_id     145500 non-null  int64
#  1   name           145500 non-null  object
#  2   born_date      143693 non-null  object
#  3   born_city      110908 non-null  object
#  4   born_region    110908 non-null  object
#  5   born_country   110908 non-null  object
#  6   NOC            145499 non-null  object
#  7   height_cm      106651 non-null  float64
#  8   weight_kg      102070 non-null  float64
#  9   died_date      33940 non-null   object
#  10  first_name     145500 non-null  object
#  11  born_datetime  143693 non-null  datetime64[ns]
#  12  born_year      143693 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(8)
# memory usage: 14.4+ MB

# %%
bios_new['born_year']  = bios_new['born_datetime'].dt.year

bios_new[['name','born_year']]
# Out:
#                          name  born_year
# 0       Jean-François Blanchy     1886.0
# 1              Arnaud Boetsch     1969.0
# 2                Jean Borotra     1898.0
# 3             Jacques Brugnon     1895.0
# 4                Albert Canet     1878.0
# ...                       ...        ...
# 145495      Polina Luchnikova     2002.0
# 145496    Valeriya Merkusheva     1999.0
# 145497        Yuliya Smirnova     1998.0
# 145498         André Foussard     1899.0
# 145499          Bill Phillips     1913.0
#
# [145500 rows x 2 columns]

# %%
bios_new['height_category']   = bios['height_cm'].apply(lambda x: 'Short' if x < 165 else ('Average' if x <185 else "Tall"))

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %% [markdown]
# ## Merging and Concatenating Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
nocs = pd.read_csv(r"C:\Users\ladvi\Downloads\noc_regions.csv")
nocs
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios_new = pd.merge(bios,nocs,left_on='born_country',right_on="NOC",how='inner')

# %%
bios_new.rename(columns ={'region':'born_country_full'},inplace=True)

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 110634      149222      Polina Luchnikova  2002-01-30            Serov
# 110635      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 110636      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 110637      149225         André Foussard  1899-05-19            Niort
# 110638      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country      NOC_x  height_cm  weight_kg  \
# ...

# %%
bios_new[bios_new['NOC_x'] != bios_new['born_country_full']]
# Out:
#         athlete_id                 name   born_date         born_city  \
# 4                5         Albert Canet  1878-04-17        Wandsworth
# 14              17           Guy Forget  1965-01-04        Casablanca
# 32              38      Helen Aitchison  1881-12-06        Sunderland
# 33              39    Geraldine Beamish  1883-06-23       Forest Gate
# 34              40         Dora Boothby  1881-08-02          Finchley
# ...            ...                  ...         ...               ...
# 110630      149215         Shakeel John  2001-07-30        Mount Hope
# 110632      149220   Landysh Falyakhova  1998-08-31  Dva Polya Artash
# 110634      149222    Polina Luchnikova  2002-01-30             Serov
# 110635      149223  Valeriya Merkusheva  1999-09-20   Moskva (Moscow)
# 110636      149224      Yuliya Smirnova  1998-05-08            Kotlas
#
#                  born_region born_country                NOC_x  height_cm  \
# ...

# %%
usa = bios[bios['born_country']=="USA"].copy()
gbr  = bios[bios['born_country']=="GBR"].copy()

# %%
new_df = pd.concat([usa,gbr])

# %%
new_df
# Out:
#         athlete_id                name   born_date         born_city  \
# 54              55       Monique Javer  1967-07-22        Burlingame
# 960            964    Xóchitl Escobedo  1968-09-17       West Covina
# 961            965   Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238      Bert Schneider  1897-07-01         Cleveland
# 1345          1352          Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                 ...         ...               ...
# 144811      148512  Benjamin Alexander  1983-05-08            London
# 144815      148517       Ashley Watson  1993-10-28      Peterborough
# 145005      148716     Peder Kongshaug  2001-08-13         Wimbledon
# 145319      149041          Axel Brown  1992-04-02         Harrogate
# 145388      149111      Jean-Luc Baker  1993-10-07           Burnley
#
#        born_region born_country                  NOC  height_cm  weight_kg  \
# ...

# %% [markdown]
# ## Handling Null Values

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25   3.99    99.75
# 1      Monday       Latte          15   5.99    89.85
# 2     Tuesday    Espresso          30   3.99   119.70
# 3     Tuesday       Latte          20   5.99   119.80
# 4   Wednesday    Espresso          35   3.99   139.65
# 5   Wednesday       Latte          25   5.99   149.75
# 6    Thursday    Espresso          40   3.99   159.60
# 7    Thursday       Latte          30   5.99   179.70
# 8      Friday    Espresso          45   3.99   179.55
# 9      Friday       Latte          35   5.99   209.65
# 10   Saturday    Espresso          45   3.99   179.55
# 11   Saturday       Latte          35   5.99   209.65
# 12     Sunday    Espresso          45   3.99   179.55
# 13     Sunday       Latte          35   5.99   209.65

# %%
coffee.loc[[0,1],'Units Sold'] = np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso         NaN   3.99    99.75
# 1      Monday       Latte         NaN   5.99    89.85
# 2     Tuesday    Espresso        30.0   3.99   119.70
# 3     Tuesday       Latte        20.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee.isna().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# price          0
# revenue        0
# dtype: int64

# %%
coffee.fillna(coffee['Units Sold'].mean())
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        35.0   3.99    99.75
# 1      Monday       Latte        35.0   5.99    89.85
# 2     Tuesday    Espresso        30.0   3.99   119.70
# 3     Tuesday       Latte        20.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee.loc[[0,1],'Units Sold'] = np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso         NaN   3.99    99.75
# 1      Monday       Latte         NaN   5.99    89.85
# 2     Tuesday    Espresso        30.0   3.99   119.70
# 3     Tuesday       Latte        20.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee.dropna()
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 2     Tuesday    Espresso        30.0   3.99   119.70
# 3     Tuesday       Latte        20.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso         NaN   3.99    99.75
# 1      Monday       Latte         NaN   5.99    89.85
# 2     Tuesday    Espresso        30.0   3.99   119.70
# 3     Tuesday       Latte        20.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %% [markdown]
# ## Aggerating Data

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios['born_city'].value_counts()
# Out:
# born_city
# Budapest           1378
# Moskva (Moscow)     883
# Oslo                708
# Stockholm           629
# Praha (Prague)      600
#                    ...
# Kirovgrad             1
# Pereiaslav            1
# Podgornyy             1
# Kudepsta              1
# Furmanov              1
# Name: count, Length: 22368, dtype: int64

# %%
bios[bios['born_country'] == "USA"]['born_region'].value_counts()
# Out:
# born_region
# California              1634
# New York                 990
# Illinois                 585
# Massachusetts            530
# Pennsylvania             530
# New Jersey               381
# Texas                    368
# Minnesota                365
# Ohio                     328
# Michigan                 319
# Washington               240
# Florida                  235
# Wisconsin                209
# Colorado                 207
# Connecticut              156
# Indiana                  150
# Oregon                   132
# Georgia                  129
# Virginia                 121
# Maryland                 117
# District of Columbia     107
# Iowa                     102
# Hawaiʻi                   95
# Kansas                    94
# Oklahoma                  93
# Louisiana                 92
# Utah                      91
# Missouri                  91
# North Carolina            86
# Arizona                   83
# New Hampshire             83
# ...

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    265
# Latte       195
# Name: Units Sold, dtype: int64

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].mean()
# Out:
# Coffee Type
# Espresso    37.857143
# Latte       27.857143
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type']).agg({'Units Sold':'sum','price':"mean"})
# Out:
#              Units Sold  price
# Coffee Type
# Espresso            265   3.99
# Latte               195   5.99

# %% [markdown]
# ## Pivot table

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25   3.99
# 1      Monday       Latte          15   5.99
# 2     Tuesday    Espresso          30   3.99
# 3     Tuesday       Latte          20   5.99
# 4   Wednesday    Espresso          35   3.99
# 5   Wednesday       Latte          25   5.99
# 6    Thursday    Espresso          40   3.99
# 7    Thursday       Latte          30   5.99
# 8      Friday    Espresso          45   3.99
# 9      Friday       Latte          35   5.99
# 10   Saturday    Espresso          45   3.99
# 11   Saturday       Latte          35   5.99
# 12     Sunday    Espresso          45   3.99
# 13     Sunday       Latte          35   5.99

# %%
pivot = coffee.pivot(columns='Coffee Type',index='Day',values='revenue')

# %%
pivot
# Out:
# Coffee Type  Espresso   Latte
# Day
# Friday         179.55  209.65
# Monday          99.75   89.85
# Saturday       179.55  209.65
# Sunday         179.55  209.65
# Thursday       159.60  179.70
# Tuesday        119.70  119.80
# Wednesday      139.65  149.75

# %%
pivot.loc['Monday','Latte']
# Out:
# np.float64(89.85000000000001)

# %%
pivot.sum()
# Out:
# Coffee Type
# Espresso    1057.35
# Latte       1168.05
# dtype: float64
