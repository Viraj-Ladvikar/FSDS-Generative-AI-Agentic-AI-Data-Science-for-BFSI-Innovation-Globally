# %% [markdown]
# # Work With Number

# %%
8
# Out:
# 8

# %%
8+1
# Out:
# 9

# %%
8-2
# Out:
# 6

# %%
8*2
# Out:
# 16

# %%
8/2
# Out:
# 4.0

# %%
8//2
# Out:
# 4

# %%
8**2

# %%
10%2
# Out:
# 0

# %% [markdown]
# ### Bodmas (Bradcket , order,division,mult,add,sub)

# %%
10+3-2*2
# Out:
# 9

# %%
10+(3-2)*2
# Out:
# 12

# %% [markdown]
# ## Works With Text

# %%
ts = '''jnwjxkslxklxsklaxlalxlaxkjnxj
najkxnknbnxbbsaxb'''
ts
# Out:
# 'jnwjxkslxklxsklaxlalxlaxkjnxj\nnajkxnknbnxbbsaxb'

# %% [markdown]
# # Variable (variable = identifier = object)
#  - variable = values

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# # DataType

# %%
# int value without decimal

# %%
i=68
i
# Out:
# 68

# %%
type(i)
# Out:
# int

# %%
 # Float value with decimal

# %%
f=100.23
f
# Out:
# 100.23

# %%
type(f)
# Out:
# float

# %%
f2 =9E3
f2
# Out:
# 9000.0

# %% [markdown]
# # BOOL

# %%
True+True
# Out:
# 2

# %%
True*True
# Out:
# 1

# %%
True-True
# Out:
# 0

# %%
True+False
# Out:
# 1

# %%
False-False
# Out:
# 0

# %% [markdown]
# # 10th -- Complex
# - a+bj (a-real part & b iscalled imaginary part where j is square root of -1 )

# %%
c = 10+20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c.conjugate()
# Out:
# (10-20j)

# %%
d=20+30j

# %%
c+d
# Out:
# (30+50j)

# %%
c.real + d.imag
# Out:
# 40.0

# %% [markdown]
# # String

# %%
s='welcome to ds ai, genai, agentic ai journey'
s
# Out:
# 'welcome to ds ai, genai, agentic ai journey'

# %%
s1="welcome to ds ai, genai, agentic ai journey"
s1

# %%
s2="""welcome to ds ai, genai, agentic ai journey"""
s2
# Out:
# 'welcome to ds ai, genai, agentic ai journey'

# %%
s3="""welcome to ds ai,
genai, agentic ai journey"""
s3
# Out:
# 'welcome to ds ai,\ngenai, agentic ai journey'

# %%
len(123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 len(123)
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
# ## String Indexing

# %%
s = "Hello Python"
s
# Out:
# 'Hello Python'

# %%
s[0]
# Out:
# 'H'

# %%
s[-3]
# Out:
# 'h'

# %%
s[8]
# Out:
# 't'

# %%
s[5]
# Out:
# ' '

# %%
s1 = "Hello Python"
s1
# Out:
# 'Hello Python'

# %%
print(id(s))
print(id(s1))
# Out:
# 1789461561648
# 1789502846704

# %%
s3="welcome"
s3="welcome"
