# %% [markdown]
# <h1 style="text-align: center;">Movie Rating Analytics</h1>

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd 
import os

# %%
movies = pd.read_csv(r"C:\Users\ladvi\Downloads\29th, 30th-  Advanced EDA project\29th, 30th-  Advanced EDA project\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film', 'Genre', 'CricticRating', 'AudienceRatings',
       'BudgetMillion', 'Year']   # Removed special chacter from column name

# %%
movies.head()
# Out:
#                     Film      Genre  CricticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CricticRating    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# if you look at the year the data type is int but when you look at the mean value it showing 2009 which is meaningless
# we have to change to categroy type 
# also from object datatype we will convert to category datatypes
# Out:
#        CricticRating  AudienceRatings  BudgetMillion         Year
# count     559.000000       559.000000     559.000000   559.000000
# mean       47.309481        58.744186      50.236136  2009.152057
# std        26.413091        16.826887      48.731817     1.362632
# min         0.000000         0.000000       0.000000  2007.000000
# 25%        25.000000        47.000000      20.000000  2008.000000
# 50%        46.000000        58.000000      35.000000  2009.000000
# 75%        70.000000        72.000000      65.000000  2010.000000
# max        97.000000        96.000000     300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies['Film'] =  movies["Film"].astype('category')
movies['Genre'] = movies['Genre'].astype('category')
movies['Year']  = movies['Year'].astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CricticRating    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.describe()
#now when you see the describt you will get only integer value mean, standard deviation which is meaning full
# Out:
#        CricticRating  AudienceRatings  BudgetMillion
# count     559.000000       559.000000     559.000000
# mean       47.309481        58.744186      50.236136
# std        26.413091        16.826887      48.731817
# min         0.000000         0.000000       0.000000
# 25%        25.000000        47.000000      20.000000
# 50%        46.000000        58.000000      35.000000
# 75%        70.000000        72.000000      65.000000
# max        97.000000        96.000000     300.000000

# %%
# HOw to start working with joint plot

import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# - basically joint plot is a scatter plot and it find the relation bewteen audience and critics
# - also if you look up you can find the uniform distributioun (crictic) and normal distribution (audiience rating )

# %%
j = sns.jointplot(data=movies,x='CricticRating',y='AudienceRatings')
plt.show()

# %%
j = sns.jointplot(data=movies,x="CricticRating",y="AudienceRatings",kind='hex')
plt.show()

# %%
j = sns.jointplot(data=movies,x="CricticRating",y="AudienceRatings",kind='reg')
plt.show()

# %%
# Histogram 

m1 = sns.distplot(movies['AudienceRatings'])
plt.show()

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movies['AudienceRatings'],bins=15)
plt.show()

# %%
n1 = plt.hist(movies.AudienceRatings, bins=15)
plt.show()

# %%
sns.set_style('white')

n1 = plt.hist(movies.AudienceRatings,bins=20)
plt.show()

# %%
n1 = plt.hist(movies.CricticRating,bins=20)
plt.show()

# %% [markdown]
# # Creating stacked histograms & this is bit tough to understand

# %%
plt.hist(movies.BudgetMillion)
plt.show()

# %%
plt.hist(movies[movies.Genre == "Drama"].BudgetMillion)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CricticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.Genre.unique
# Out:
# <bound method Series.unique of 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']>

# %%
# Below plots are stacked histogram because overlaped 


plt.hist(movies[movies.Genre == 'Action'].BudgetMillion,bins=20)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillion,bins=20)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillion,bins=20)
plt.legend()
plt.show()

# %%
plt.hist([movies[movies.Genre == "Action"].BudgetMillion,\
          movies[movies.Genre == "Drama"].BudgetMillion,\
          movies[movies.Genre == 'Thriller'].BudgetMillion,\
          movies[movies.Genre == 'Comedy'].BudgetMillion
         ],bins=20,stacked=True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data=movies,x = 'CricticRating',y='AudienceRatings',fit_reg=False)
plt.show()

# %%
vis1 = sns.lmplot(data=movies, x= 'CricticRating',y='AudienceRatings',fit_reg=False,hue='Genre')
plt.show()

# %%
vis1 = sns.lmplot(data=movies,x="CricticRating",y="AudienceRatings",fit_reg=False,hue='Genre',aspect=1)
plt.show()

# %% [markdown]
# # Kernal Density Estimate plot ( KDE PLOT)
# # how can i visulize audience rating & critics rating . using scatterplot

# %%
vis1 = sns.kdeplot(x = movies.CricticRating,y = movies.AudienceRatings)
plt.show()

# %%
k1 = sns.kdeplot(x = movies.CricticRating,y = movies.AudienceRatings,shade = True,shade_lowest =False,cmap='Reds')
plt.show()

# %%
k2 = sns.kdeplot(x = movies.CricticRating,y=movies.AudienceRatings,shade_lowest=False,camp="Greens_r")
plt.show()

# %%
sns.set_style('dark')
k1 = sns.kdeplot(x = movies.BudgetMillion,y = movies.AudienceRatings,shade_lowest=False,cmap='Greens_r')
plt.show()

# %%
sns.set_style('dark')
k1 = sns.kdeplot(x= movies.BudgetMillion,y = movies.AudienceRatings)
plt.show()

# %%
 sns.kdeplot(y=movies.CricticRating,x=movies.BudgetMillion)
plt.show()

# %%
# Subplots 
f,ax = plt.subplots(1,2,figsize=(8,4))
plt.show()

# %%
f,ax = plt.subplots(1,2,figsize=(8,4))

k1 = sns.kdeplot(x=movies.BudgetMillion,y=movies.CricticRating,ax=ax[0])
k2 = sns.kdeplot(x=movies.BudgetMillion,y=movies.AudienceRatings,ax = ax[1])
plt.show()

# %%
ax
# Out:
# array([<Axes: xlabel='BudgetMillion', ylabel='CricticRating'>,
#        <Axes: xlabel='BudgetMillion', ylabel='AudienceRatings'>],
#       dtype=object)

# %%
# Box Plot 

w = sns.boxplot(data=movies,x='Genre',y='CricticRating')
plt.show()

# %%
# vviolin plot 
sns.violinplot(x=movies.Genre,y=movies.CricticRating)
plt.show()

# %%
# boxplot

sns.boxplot(x=movies.Genre,y = movies.CricticRating)
plt.show()

# %%
z = sns.violinplot(data=movies[movies.Genre == "Drama"],x='Year',y='CricticRating')
plt.show()

# %% [markdown]
# ## Creating A FacetGrid

# %%
g = sns.FacetGrid(movies,row='Genre',col="Year",hue='Genre')
plt.show()

# %%
plt.scatter(movies.CricticRating,movies.AudienceRatings)
plt.show()

# %%
g = sns.FacetGrid(movies,row='Genre',col='Year',hue="Genre")
g = g.map(plt.scatter,'CricticRating','AudienceRatings')
plt.show()

# %%
g = sns.FacetGrid(movies,row="Genre",col="Year",hue="Genre")
g = g.map(plt.hist,'BudgetMillion')
plt.show()

# %%
#
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CricticRating', 'AudienceRatings',**kws ) #scatterplots are mapped in facetgrid
plt.show()

# %%
sns.set_style('darkgrid')

f,ax=plt.subplots(2,2,figsize=(8,8))

k1 = sns.kdeplot(x=movies.BudgetMillion,y=movies.CricticRating,ax=ax[0,0])
k2 = sns.kdeplot(x=movies.BudgetMillion,y=movies.CricticRating,ax= ax[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CricticRating', ax=ax[1,0])

k4 = sns.kdeplot(x=movies.CricticRating,y=movies.AudienceRatings,shade = True,shade_lowest=False,cmap='Reds',ax=ax[1,1])
k4b = sns.kdeplot(x= movies.CricticRating,y =  movies.AudienceRatings,cmap='Reds',ax = ax[1,1])
plt.show()
