# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
num = int(input())

if num%2==0:
    print("even")
# Out:
#  9

# %%
i = 1
while i<=5:
    print("data")
    i+=1
# Out:
# data
# data
# data
# data
# data

# %%
i = 1
while i<=4:
    j=0
    while j<=3:
        print(i*j,end=" ")
        j+=1
    print()
    i+=1
# Out:
# 0 1 2 3
# 0 2 4 6
# 0 3 6 9
# 0 4 8 12
