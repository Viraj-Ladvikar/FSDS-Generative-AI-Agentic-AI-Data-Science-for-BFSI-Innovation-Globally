# %% [markdown]
# # TUPLE
#  - Enclosed within the Braces ()
#  - Maintain Insertion Order
#  - Indexing And Slicing Allowed
#  - Immutable
#  - Duplicate allowed
#  - Multiple DataType Allowed

# %% [markdown]
# ## For Single value it should Ended with comma other wise notrt treated as tuple

# %%
t = (10)
print(type(t))
# Out:
# <class 'int'>

# %%
t=(10,)
print(type(t))
# Out:
# <class 'tuple'>

# %% [markdown]
# ## Creation of Tuple

# %%
t = ()
print(type(t))
print(t)
# Out:
# <class 'tuple'>
# ()

# %%
t = 10,20,30
print(type(t))
print(t)
# Out:
# <class 'tuple'>
# (10, 20, 30)

# %%
t = (10,20,30)
print(type(t))
print(t)
# Out:
# <class 'tuple'>
# (10, 20, 30)

# %%
t = (10,)
print(type(t))
print(t)
# Out:
# <class 'tuple'>
# (10,)

# %%
t = 10,
print(type(t))
print(t)
# Out:
# <class 'tuple'>
# (10,)

# %%
t = eval(input())
print(t)
print(type(t))
# Out:
#  (10,2,304,0)
# (10, 2, 304, 0)
# <class 'tuple'>

# %% [markdown]
# ## Accessing Elemnt of tuple

# %% [markdown]
# ### Access using Index

# %%
t= 10,20,30,40
t
# Out:
# (10, 20, 30, 40)

# %%
t[3]
# Out:
# 40

# %%
t[-2]
# Out:
# 30

# %%
t[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t[9]
#
# IndexError: tuple index out of range

# %% [markdown]
# ### Access Using Slicing

# %%
t =(10,20,30,40)
t
# Out:
# (10, 20, 30, 40)

# %%
t[0:]
# Out:
# (10, 20, 30, 40)

# %%
t[::-1]
# Out:
# (40, 30, 20, 10)

# %%
t[2:100]
# Out:
# (30, 40)

# %% [markdown]
# ## Tuple Immutability
#  - Tuple is immutable

# %%
t= tuple(range(1,10))
t
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
t[0]
# Out:
# 1

# %%
t[0]=10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 t[0]=10
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Mathemaitcal Operator For tuple
#    - Concateinate operator +
#    - repetition operator *

# %%
t1 = (10,20,30,40)
t1
# Out:
# (10, 20, 30, 40)

# %%
t2=(11,22,33,44)
t2
# Out:
# (11, 22, 33, 44)

# %%
t1+t2
# Out:
# (10, 20, 30, 40, 11, 22, 33, 44)

# %%
t*2
# Out:
# (10, 20, 30, 40, 10, 20, 30, 40)

# %% [markdown]
# ## Function in tuple
#  - Count return the number of occurance of element
#  - return the elemnt at thet specified index

# %%
t=(10,20,30,40,20,30)
t
# Out:
# (10, 20, 30, 40, 20, 30)

# %% [markdown]
# ### Count() :- return the occurance of the element

# %%
t.count(10)
# Out:
# 1

# %%
t.count(20)
# Out:
# 2

# %%
t.count(99)
# Out:
# 0

# %% [markdown]
# ### index() :- return the element of the sepcified index position first occurance

# %%
t.index(10)
# Out:
# 0

# %%
t.index(30)
# Out:
# 2

# %%
t.index(40)
# Out:
# 3

# %%
t.index(99)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 t.index(99)
#
# ValueError: tuple.index(x): x not in tuple

# %%
print(num)
print(type(num))
# Out:
#  (222,33,44)
# (222, 33, 44)
# <class 'tuple'>

# %% [markdown]
# ## Tuple Packing and unpacking

# %%
a=10
b=20
c=30
t = a,b,c
print(t)
print(type(t))
# Out:
# (10, 20, 30)
# <class 'tuple'>

# %%
t = (90,80,60)
a,b,c = t
print(a,type(a))
print(b,type(b))
print(c,type(a))
# Out:
# 90 <class 'int'>
# 80 <class 'int'>
# 60 <class 'int'>
