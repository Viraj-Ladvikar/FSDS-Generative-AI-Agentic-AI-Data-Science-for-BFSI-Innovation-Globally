# %%
# first line comment
spam = 1  # second line
text = '# this is not comment because it inside quotes'

# %%
2+2
# Out:
# 4

# %%
'doesn\'t'
# Out:
# "doesn't"

# %%
"does\"t"
# Out:
# 'does"t'

# %%
'yes," they said'
# Out:
# 'yes," they said'

# %%
"\yes,\" they said"
# Out:
# '\\yes," they said'

# %%
'"Isn\'t," they said'
# Out:
# '"Isn\'t," they said'

# %%
s= "first line.\nsecond line"
s
# Out:
# 'first line.\nsecond line'

# %%
s= "first line.\nsecond line"
print(s)
# Out:
# first line.
# second line

# %%
print('c:\some\name')
# Out:
# c:\some
# ame

# %%
print(r"c:\some\name")
# Out:
# c:\some\name

# %%
print("""\
  usage thingy [OPTIONS]
  -h DISPLAY this usage message""")
# Out:
#   usage thingy [OPTIONS]
#   -h DISPLAY this usage message

# %%
3*'un'+'ium'
# Out:
# 'unununium'

# %%
'py' 'thon'
# Out:
# 'python'

# %%
word = 'python'
word[0]
word[5]
# Out:
# 'n'

# %%
word="python"
word[-2]
# Out:
# 'o'

# %%
word="python"
word[2:5]
# Out:
# 'tho'

# %%
word="python"
word[-1:-4:-2]
# Out:
# 'nh'

# %%
word="python"
word[:]
# Out:
# 'python'

# %%
word[2:0]
# Out:
# ''

# %%
word="Python"
word[::-1]
# Out:
# 'nohtyP'

# %%
word="Python"
word[2:]
# Out:
# 'thon'

# %%
words="python"
len(words)
# Out:
# 6

# %%
squares= [1,2,3,4,5,6]
squares
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
squares[0]
# Out:
# 1

# %%
squares[2:4]
# Out:
# [3, 4]

# %%
squares+[7,8,9]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
cube=[1,2,4,5,6]
4**3
# Out:
# 64

# %%
cube[4]=64

# %%
cube
# Out:
# [1, 2, 4, 5, 64]

# %%
cube.append(42)

# %%
cube
# Out:
# [1, 2, 4, 5, 64, 42]

# %%
cubes = cube[::-1]

# %%
cubes
# Out:
# [42, 64, 5, 4, 2, 1]

# %%
rgb=["REd","green","blue"]
rgba= rgb
id(rgba)==id(rgb)
# Out:
# True

# %%
letters=['a','b','c','d','e']
letters
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
letters[2:5] = ['v','u','w']

# %%
letters
# Out:
# ['a', 'b', 'v', 'u', 'w']

# %%
letters[2:5]=[]

# %%
letters
# Out:
# ['a', 'b']

# %%
len(letters)
# Out:
# 2
